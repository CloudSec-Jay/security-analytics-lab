# %% [markdown]
# # Project: SIEM Threat Hunting & Lateral Movement (MySQL)
#
# **Mission:** A sophisticated threat actor is inside the network. They are using "Living off the Land" (LotL) techniques—using legitimate system tools like `powershell.exe` and `wmic.exe` to avoid detection.
#
# **Objective:** Connect to your MySQL-backed SIEM and use advanced SQL queries to trace the attacker's path.
#
# ---

# %% [markdown]
# ## Part 1: Connecting to the SIEM
# Connect to the `siem_db` in MySQL. You should have three tables: `auth_logs`, `process_logs`, and `net_logs`.

# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import matplotlib.pyplot as plt

# YOUR CODE HERE

# %% [markdown]
# ## Part 2: Detection - Living off the Land
# Attacker often use common tools for malicious purposes.
#
# **Task:** Write a SQL query to find all executions of `powershell.exe` that include suspicious arguments like `-ExecutionPolicy Bypass` or `-EncodedCommand`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 3: Correlation - Lateral Movement
# When an attacker moves from one machine to another, we see an Authentication log followed by a Network Connection.
#
# **Task:** Perform a SQL **JOIN** between `auth_logs` and `net_logs` on `source_ip` and `timestamp` (within a 5-second window). This identifies successful logins that immediately initiated network scans.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 4: Pattern Detection - Beaconing
# Attacker malware often "beacons" home to a C2 server at regular intervals.
#
# **Task:** Use `groupby` on `destination_ip` and find the **Standard Deviation** of the time differences between requests. A low standard deviation means the traffic is automated and regular.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 5: Threat Incident Report
# **Task:** Create a final visualization showing the "Attack Timeline." Plot the number of suspicious events over time to identify when the breach occurred.

# %%
# YOUR CODE HERE
