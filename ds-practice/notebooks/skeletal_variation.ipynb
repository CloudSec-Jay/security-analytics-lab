# %% [markdown]
# # Lab: Forensic Anthropology & SQL (Intermediate)
#
# **Objective:** Use skeletal measurements to identify biological traits.
#
# **Rules:**
# 1. Do not ask for the full code. Try to solve each task using documentation or your existing knowledge.
# 2. If you get stuck, ask for the **concept** or the **syntax pattern**.
# ---

# %% [markdown]
# ## Part 1: Database Infrastructure
# We will use `SQLAlchemy` to create a local database. I have provided the setup code below so you have data to work with.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Setup
engine = create_engine('sqlite:///forensics.db')
df_raw = pd.read_csv('../data/adult-human-skeleton.csv')
df_raw.to_sql('skeletons', engine, if_exists='replace', index=False)

print("Infrastructure Ready. Table 'skeletons' is available in 'forensics.db'.")

# %% [markdown]
# ## Part 2: SQL Discovery
# **Task:** Write a SQL query to retrieve all individuals older than 40 years old from the `skeletons` table.
#
# *Hint: Use `pd.read_sql(query, engine)`*

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 3: Correlation Analysis
# In forensic cases, we often find only one bone. We need to know which bone is most likely to predict the person's height.
#
# **Task:** Load the full table and find the **correlation matrix** for `height_cm`, `femur_length_cm`, and `humerus_length_cm`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 4: Pelvic Dimorphism
# Men and women have different skeletal structures, particularly in the pelvis for childbirth.
#
# **Task:** Use a `groupby` operation to find the **mean** and **standard deviation** of `pelvis_width_cm` for each sex.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 5: Feature Engineering
# Forensic scientists often use ratios because they are independent of the individual's size.
#
# **Task:** Create a new column `skull_pelvis_ratio` (Skull Width / Pelvis Width). Then, find the average ratio for each sex.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 6: Visualization for the Courtroom
# You need to present your findings to a jury. A scatter plot showing how Femur Length and Pelvis Width can separate the two sexes is required.
#
# **Task:** Create a scatter plot.
# - X-axis: `femur_length_cm`
# - Y-axis: `pelvis_width_cm`
# - Color the dots by `sex` (e.g., Male = Blue, Female = Pink).

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Final Analysis
# Looking at your scatter plot, describe in plain English how you would identify a skeleton if you only had the femur and the pelvis.
#
# **Answer:** [Type your answer here]
